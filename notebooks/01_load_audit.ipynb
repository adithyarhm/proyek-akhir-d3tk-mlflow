# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/data/raw/node1.csv')
df2 = pd.read_csv('/data/raw/node2.csv')
df3 = pd.read_csv('/data/raw/node3.csv')
df4 = pd.read_csv('/data/raw/node4.csv')
df5 = pd.read_csv('/data/raw/node5.csv')
df6 = pd.read_csv('/data/raw/node6.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df1 = pd.read_csv('data\raw\node1.csv')
#       2 df2 = pd.read_csv('data\raw\node2.csv')
#       3 df3 = pd.read_csv('data\raw\node3.csv')
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# OSError: [Errno 22] Invalid argument: 'data\raw\node1.csv'

# %%
for i in range(1,7):
    print(f"cek head dari node{i}")
    print(eval(f"df{i}").head())
# Out:
# cek head dari node1
#    Node         Location Weather             DateTime  H2S  SO2  Humidity  \
# 0     1  Dekat uap panas   Cerah  12/22/2025 11:53:00   43  149     87.03
# 1     1  Dekat uap panas   Cerah  12/22/2025 11:53:02   40  149     87.03
# 2     1  Dekat uap panas   Cerah  12/22/2025 11:53:04   40  149     87.23
# 3     1  Dekat uap panas   Cerah  12/22/2025 11:53:06   40  141     87.23
# 4     1  Dekat uap panas   Cerah  12/22/2025 11:53:08   40  133     87.23
#
#    Temperature  WindsSpeed
# 0        17.94        1.44
# 1        17.94        0.72
# 2        17.94        0.72
# 3        17.94        0.72
# 4        17.93        0.72
# cek head dari node2
#    Node               Location  Weather             DateTime  H2S  SO2  \
# 0     2  Dekat sumber mata air  Mendung  12/22/2025 13:25:00   18   36
# 1     2  Dekat sumber mata air  Mendung  12/22/2025 13:25:02   18   36
# 2     2  Dekat sumber mata air  Mendung  12/22/2025 13:25:04   18   36
# 3     2  Dekat sumber mata air  Mendung  12/22/2025 13:25:06   18   36
# 4     2  Dekat sumber mata air  Mendung  12/22/2025 13:25:08   18   36
#
#    Humidity  Temperature  WindsSpeed
# 0     83.37        19.41        5.76
# 1     83.37        19.41        5.76
# 2     84.11        19.32        6.84
# 3     84.11        19.32        5.40
# 4     84.11        19.23        5.40
# cek head dari node3
#    Node    Location  Weather             DateTime  H2S  SO2  Humidity  \
# 0     3  Hutan Mati  Mendung  12/22/2025 15:25:00  121  453     95.85
# 1     3  Hutan Mati  Mendung  12/22/2025 15:25:02  121  453     95.85
# 2     3  Hutan Mati  Mendung  12/22/2025 15:25:04  121  448     96.05
# 3     3  Hutan Mati  Mendung  12/22/2025 15:25:06  121  448     96.05
# 4     3  Hutan Mati  Mendung  12/22/2025 15:25:08  121  448     96.05
#
#    Temperature  WindsSpeed
# 0        17.57        4.32
# 1        17.57        4.68
# 2        17.57        4.32
# 3        17.57        4.32
# 4        17.57        4.32
# cek head dari node4
#    Node         Location      Weather             DateTime  H2S  SO2  \
# 0     4  Area Pengunjung  Hujan Kabut  12/22/2025 15:42:00   28   78
# 1     4  Area Pengunjung  Hujan Kabut  12/22/2025 15:42:02   28   78
# 2     4  Area Pengunjung  Hujan Kabut  12/22/2025 15:42:04   28   78
# 3     4  Area Pengunjung  Hujan Kabut  12/22/2025 15:42:06   28   65
# 4     4  Area Pengunjung  Hujan Kabut  12/22/2025 15:42:08   30   65
#
#    Humidity  Temperature  WindsSpeed
# 0       100        16.07        1.44
# 1       100        16.07        2.16
# 2       100        16.07        2.16
# 3       100        16.04        2.16
# 4       100        16.04        2.52
# cek head dari node5
#    Node Location      Weather             DateTime  H2S  SO2  Humidity  \
# 0     5      Goa  Hujan Kabut  12/22/2025 16:13:00   37  199       100
# 1     5      Goa  Hujan Kabut  12/22/2025 16:13:02   37  167       100
# 2     5      Goa  Hujan Kabut  12/22/2025 16:13:04   37  167       100
# 3     5      Goa  Hujan Kabut  12/22/2025 16:13:06   36  149       100
# 4     5      Goa  Hujan Kabut  12/22/2025 16:13:08   36  149       100
#
#    Temperature  WindsSpeed
# 0        15.38        1.44
# 1        15.34        1.08
# 2        15.34        1.08
# 3        15.30        1.08
# 4        15.30        0.72
# cek head dari node6
#    Node                 Location      Weather             DateTime  H2S  SO2  \
# 0     6  Tangga Masuk Pengunjung  Hujan Kabut  12/22/2025 16:38:00    9  162
# 1     6  Tangga Masuk Pengunjung  Hujan Kabut  12/22/2025 16:38:02   12  162
# 2     6  Tangga Masuk Pengunjung  Hujan Kabut  12/22/2025 16:38:04   12  175
# 3     6  Tangga Masuk Pengunjung  Hujan Kabut  12/22/2025 16:38:06   15  175
# 4     6  Tangga Masuk Pengunjung  Hujan Kabut  12/22/2025 16:38:08   15  186
#
#    Humidity  Temperature  WindsSpeed
# 0       100        15.60        0.00
# 1       100        15.60        0.36
# 2       100        15.54        0.36
# 3       100        15.54        0.36
# 4       100        15.54        0.36

# %%
## insert data dari bu giva

# node1
elevation1 = 2101
latitude1 = -7.166870
longitude1 = 107.401387
df1['Elevation'] = elevation1
df1['Latitude'] = latitude1
df1['Longitude'] = longitude1

# node2
elevation2 = 2195
latitude2 = -7.167397
longitude2 = 107.401775
df2['Elevation'] = elevation2
df2['Latitude'] = latitude2
df2['Longitude'] = longitude2

# node3
elevation3 = 2196
latitude3 = -7.167415
longitude3 = 107.402914
df3['Elevation'] = elevation3
df3['Latitude'] = latitude3
df3['Longitude'] = longitude3

#node4
elevation4 = 2193
latitude4 = -7.166614
longitude4 = 107.403483
df4['Elevation'] = elevation4
df4['Latitude'] = latitude4
df4['Longitude'] = longitude4

#node5
elevation5 = 2194
latitude5 = -7.166418
longitude5 = 107.404100
df5['Elevation'] = elevation5
df5['Latitude'] = latitude5
df5['Longitude'] = longitude5

#node6
elevation6 = 2200
latitude6 = -7.166833
longitude6 = 107.40411
df6['Elevation'] = elevation6
df6['Latitude'] = latitude6
df6['Longitude'] = longitude6

# %%
for i in range(1,7):
    print(f"cek head dari node{i}")
    print(eval(f"df{i}").info())
# Out:
# Panjang df1: 739 baris
# cek head dari node1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 739 entries, 0 to 738
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Node         739 non-null    int64
#  1   Location     739 non-null    object
#  2   Weather      739 non-null    object
#  3   DateTime     739 non-null    object
#  4   H2S          739 non-null    int64
#  5   SO2          739 non-null    int64
#  6   Humidity     739 non-null    float64
#  7   Temperature  739 non-null    float64
#  8   WindsSpeed   739 non-null    float64
#  9   Elevation    739 non-null    int64
#  10  Latitude     739 non-null    float64
#  11  Longitude    739 non-null    float64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 69.4+ KB
# None
# Panjang df2: 843 baris
# cek head dari node2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Node         843 non-null    int64
#  1   Location     843 non-null    object
#  2   Weather      843 non-null    object
#  3   DateTime     843 non-null    object
#  4   H2S          843 non-null    int64
#  5   SO2          843 non-null    int64
#  6   Humidity     843 non-null    float64
#  7   Temperature  843 non-null    float64
#  8   WindsSpeed   843 non-null    float64
#  9   Elevation    843 non-null    int64
#  10  Latitude     843 non-null    float64
#  11  Longitude    843 non-null    float64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 79.2+ KB
# None
# Panjang df3: 247 baris
# cek head dari node3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Node         247 non-null    int64
#  1   Location     247 non-null    object
#  2   Weather      247 non-null    object
#  3   DateTime     247 non-null    object
#  4   H2S          247 non-null    int64
#  5   SO2          247 non-null    int64
#  6   Humidity     247 non-null    float64
#  7   Temperature  247 non-null    float64
#  8   WindsSpeed   247 non-null    float64
#  9   Elevation    247 non-null    int64
#  10  Latitude     247 non-null    float64
#  11  Longitude    247 non-null    float64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 23.3+ KB
# None
# Panjang df4: 447 baris
# cek head dari node4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Node         447 non-null    int64
#  1   Location     447 non-null    object
#  2   Weather      447 non-null    object
#  3   DateTime     447 non-null    object
#  4   H2S          447 non-null    int64
#  5   SO2          447 non-null    int64
#  6   Humidity     447 non-null    int64
#  7   Temperature  447 non-null    float64
#  8   WindsSpeed   447 non-null    float64
#  9   Elevation    447 non-null    int64
#  10  Latitude     447 non-null    float64
#  11  Longitude    447 non-null    float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 42.0+ KB
# None
# Panjang df5: 452 baris
# cek head dari node5
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Node         452 non-null    int64
#  1   Location     452 non-null    object
#  2   Weather      452 non-null    object
#  3   DateTime     452 non-null    object
#  4   H2S          452 non-null    int64
#  5   SO2          452 non-null    int64
#  6   Humidity     452 non-null    int64
#  7   Temperature  452 non-null    float64
#  8   WindsSpeed   452 non-null    float64
#  9   Elevation    452 non-null    int64
#  10  Latitude     452 non-null    float64
#  11  Longitude    452 non-null    float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 42.5+ KB
# None
# Panjang df6: 167 baris
# cek head dari node6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Node         167 non-null    int64
#  1   Location     167 non-null    object
#  2   Weather      167 non-null    object
#  3   DateTime     167 non-null    object
#  4   H2S          167 non-null    int64
#  5   SO2          167 non-null    int64
#  6   Humidity     167 non-null    int64
#  7   Temperature  167 non-null    float64
#  8   WindsSpeed   167 non-null    float64
#  9   Elevation    167 non-null    int64
#  10  Latitude     167 non-null    float64
#  11  Longitude    167 non-null    float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 15.8+ KB
# None

# %%
for i in range(1, 7):
    df = eval(f"df{i}")

    # ubah penamaan kolom
    df.rename(columns={
        'Node': 'node',
        'Location': 'location',
        'Weather': 'weather',
        'DateTime': 'datetime',
        'H2S': 'h2s',
        'SO2': 'so2',
        'Humidity': 'hum',
        'Temperature': 'temp',
        'WindsSpeed': 'windspeed',
        'Elevation': 'elevation',
        'Latitude': 'latitude',
        'Longitude': 'longitude'
    }, inplace=True)

    # convert tipe data
    df['datetime'] = pd.to_datetime(df['datetime'])
    df['h2s'] = df['h2s'].astype('float64')
    df['so2'] = df['so2'].astype('float64')
    df['hum'] = df['hum'].astype('float64')
    df['elevation'] = df['elevation'].astype('float64')

    print(f"setelah perubahan:")
    df.info()
# Out:
# setelah perubahan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 739 entries, 0 to 738
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   node       739 non-null    int64
#  1   location   739 non-null    object
#  2   weather    739 non-null    object
#  3   datetime   739 non-null    datetime64[ns]
#  4   h2s        739 non-null    float64
#  5   so2        739 non-null    float64
#  6   hum        739 non-null    float64
#  7   temp       739 non-null    float64
#  8   windspeed  739 non-null    float64
#  9   elevation  739 non-null    float64
#  10  latitude   739 non-null    float64
#  11  longitude  739 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(2)
# memory usage: 69.4+ KB
# setelah perubahan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   node       843 non-null    int64
#  1   location   843 non-null    object
#  2   weather    843 non-null    object
#  3   datetime   843 non-null    datetime64[ns]
#  4   h2s        843 non-null    float64
#  5   so2        843 non-null    float64
#  6   hum        843 non-null    float64
#  7   temp       843 non-null    float64
#  8   windspeed  843 non-null    float64
#  9   elevation  843 non-null    float64
#  10  latitude   843 non-null    float64
#  11  longitude  843 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(2)
# memory usage: 79.2+ KB
# setelah perubahan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   node       247 non-null    int64
#  1   location   247 non-null    object
#  2   weather    247 non-null    object
#  3   datetime   247 non-null    datetime64[ns]
#  4   h2s        247 non-null    float64
#  5   so2        247 non-null    float64
#  6   hum        247 non-null    float64
#  7   temp       247 non-null    float64
#  8   windspeed  247 non-null    float64
#  9   elevation  247 non-null    float64
#  10  latitude   247 non-null    float64
#  11  longitude  247 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(2)
# memory usage: 23.3+ KB
# setelah perubahan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   node       447 non-null    int64
#  1   location   447 non-null    object
#  2   weather    447 non-null    object
#  3   datetime   447 non-null    datetime64[ns]
#  4   h2s        447 non-null    float64
#  5   so2        447 non-null    float64
#  6   hum        447 non-null    float64
#  7   temp       447 non-null    float64
#  8   windspeed  447 non-null    float64
#  9   elevation  447 non-null    float64
#  10  latitude   447 non-null    float64
#  11  longitude  447 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(2)
# memory usage: 42.0+ KB
# setelah perubahan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   node       452 non-null    int64
#  1   location   452 non-null    object
#  2   weather    452 non-null    object
#  3   datetime   452 non-null    datetime64[ns]
#  4   h2s        452 non-null    float64
#  5   so2        452 non-null    float64
#  6   hum        452 non-null    float64
#  7   temp       452 non-null    float64
#  8   windspeed  452 non-null    float64
#  9   elevation  452 non-null    float64
#  10  latitude   452 non-null    float64
#  11  longitude  452 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(2)
# memory usage: 42.5+ KB
# setelah perubahan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   node       167 non-null    int64
#  1   location   167 non-null    object
#  2   weather    167 non-null    object
#  3   datetime   167 non-null    datetime64[ns]
#  4   h2s        167 non-null    float64
#  5   so2        167 non-null    float64
#  6   hum        167 non-null    float64
#  7   temp       167 non-null    float64
#  8   windspeed  167 non-null    float64
#  9   elevation  167 non-null    float64
#  10  latitude   167 non-null    float64
#  11  longitude  167 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(2)
# memory usage: 15.8+ KB

# %%
list_df = [df1, df2, df3, df4, df5, df6]
df_combined = pd.concat(list_df, ignore_index=True)
print("setelah digabungkan:")
df_combined.tail()
# Out:
# setelah digabungkan:
#       node                 location      weather            datetime  h2s  \
# 2890     6  Tangga Masuk Pengunjung  Hujan Kabut 2025-12-22 16:43:24  7.0
# 2891     6  Tangga Masuk Pengunjung  Hujan Kabut 2025-12-22 16:43:26  7.0
# 2892     6  Tangga Masuk Pengunjung  Hujan Kabut 2025-12-22 16:43:28  7.0
# 2893     6  Tangga Masuk Pengunjung  Hujan Kabut 2025-12-22 16:43:30  7.0
# 2894     6  Tangga Masuk Pengunjung  Hujan Kabut 2025-12-22 16:43:32  7.0
#
#        so2    hum   temp  windspeed  elevation  latitude  longitude
# 2890  65.0  100.0  14.71       0.36     2200.0 -7.166833  107.40411
# 2891  65.0  100.0  14.71       0.72     2200.0 -7.166833  107.40411
# 2892  62.0  100.0  14.71       0.72     2200.0 -7.166833  107.40411
# 2893  62.0  100.0  14.71       0.72     2200.0 -7.166833  107.40411
# 2894  65.0  100.0  14.71       0.36     2200.0 -7.166833  107.40411

# %%
df_combined.to_csv('node_combined.csv', index=False)
